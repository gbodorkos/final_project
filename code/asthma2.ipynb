# %% [markdown]
# # 1. Importing Local Data for Better Health dataset

# %% [markdown]
# This dataset contains the "Current asthma among adults aged >=18 years" data which I will be using for calculations later

# %%
import pandas as pd

# %%
df = pd.read_excel('PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2020_release.xlsx')

# %%
df_asthma=df.loc[df['MeasureId'] == 'CASTHMA']

# %% [markdown]
# Here I select Alabama for my first regression model

# %%
df_asthmaalabama=df_asthma.loc[df_asthma['StateDesc'] == 'Alabama']

# %%
df_asthmaalabama
# Out:
#        Year StateAbbr StateDesc  CountyName  CountyFIPS  LocationName  \
# 29     2018        AL   Alabama         Lee        1081    1081041900
# 3306   2018        AL   Alabama     Calhoun        1015    1015000200
# 3327   2018        AL   Alabama     Barbour        1005    1005950500
# 3401   2018        AL   Alabama    Cleburne        1029    1029959500
# 3471   2018        AL   Alabama      Etowah        1055    1055000200
# ...     ...       ...       ...         ...         ...           ...
# 44784  2018        AL   Alabama      Wilcox        1131    1131035100
# 46386  2018        AL   Alabama  Washington        1129    1129044000
# 48683  2018        AL   Alabama     Winston        1133    1133965600
# 49188  2018        AL   Alabama     Winston        1133    1133965501
# 49858  2018        AL   Alabama      Wilcox        1131    1131035200
#
#       DataSource         Category  \
# 29         BRFSS  Health Outcomes
# 3306       BRFSS  Health Outcomes
# ...

# %%
df_asthmaalabamadata=df_asthmaalabama["Data_Value"]

# %%
df_asthmaalabamadata
# Out:
# 29        9.8
# 3306     12.3
# 3327     10.8
# 3401     10.5
# 3471     12.4
#          ...
# 44784    12.2
# 46386    10.6
# 48683    11.1
# 49188    10.5
# 49858    12.4
# Name: Data_Value, Length: 1175, dtype: float64

# %%
df_asthmaalabama.dtypes
# Out:
# Year                            int64
# StateAbbr                      object
# StateDesc                      object
# CountyName                     object
# CountyFIPS                      int64
# LocationName                    int64
# DataSource                     object
# Category                       object
# Measure                        object
# Data_Value_Unit                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# TotalPopulation                 int64
# Geolocation                    object
# LocationID                      int64
# CategoryID                     object
# MeasureId                      object
# DataValueTypeID                object
# Short_Question_Text            object
# dtype: object

# %% [markdown]
# This is the dataset with the PM 2.5 pollution levels measured in Alabama air pollution detection stations

# %%
pm25 = pd.read_excel('alabama3.xlsx')

# %%
pm25
# Out:
#       Unnamed: 0  pm 2.5
# 0              1      21
# 1              2      19
# 2              3      34
# 3              4      27
# 4              5      24
# ...          ...     ...
# 1170        1171      42
# 1171        1172      60
# 1172        1173      29
# 1173        1174      26
# 1174        1175      43
#
# [1175 rows x 2 columns]

# %%
pollution = [df_asthmaalabamadata, pm25]

result2 = pd.concat(pollution)

# %%
data = [df, pm25]

# %%
result = pd.concat(data)

# %%
df_asthmaalabama.to_excel('asthmaa.xlsx')

# %%
df = pd.read_excel('asthmawpm25.xlsx')

# %%
df
# Out:
#       Unnamed: 0  Year StateAbbr StateDesc  CountyName  CountyFIPS  \
# 0             29  2018        AL   Alabama         Lee        1081
# 1           3306  2018        AL   Alabama     Calhoun        1015
# 2           3327  2018        AL   Alabama     Barbour        1005
# 3           3401  2018        AL   Alabama    Cleburne        1029
# 4           3471  2018        AL   Alabama      Etowah        1055
# ...          ...   ...       ...       ...         ...         ...
# 1170       44784  2018        AL   Alabama      Wilcox        1131
# 1171       46386  2018        AL   Alabama  Washington        1129
# 1172       48683  2018        AL   Alabama     Winston        1133
# 1173       49188  2018        AL   Alabama     Winston        1133
# 1174       49858  2018        AL   Alabama      Wilcox        1131
#
#       LocationName DataSource         Category  \
# 0       1081041900      BRFSS  Health Outcomes
# 1       1015000200      BRFSS  Health Outcomes
# ...

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df2=df['Data_Value']

# %%
df2
# Out:
# 0        9.8
# 1       12.3
# 2       10.8
# 3       10.5
# 4       12.4
#         ...
# 1170    12.2
# 1171    10.6
# 1172    11.1
# 1173    10.5
# 1174    12.4
# Name: Data_Value, Length: 1175, dtype: float64

# %%
df2 = df[['Data_Value','PM 2.5']]

# %%
df2
# Out:
#       Data_Value  PM 2.5
# 0            9.8      21
# 1           12.3      19
# 2           10.8      34
# 3           10.5      27
# 4           12.4      24
# ...          ...     ...
# 1170        12.2      42
# 1171        10.6      60
# 1172        11.1      29
# 1173        10.5      26
# 1174        12.4      43
#
# [1175 rows x 2 columns]

# %% [markdown]
# Applying a linear regression model

# %%
X=df2.drop(columns=['Data_Value']) 
y=df2['Data_Value']

# %%
X.shape
# Out:
# (1175, 1)

# %%
y.shape
# Out:
# (1175,)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
import math

# %%
ln=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model=ln.fit(X_train,y_train)

# %%
y_pred =ln.predict(X_test)

# %%
r2_score(y_test, y_pred)
# Out:
# -0.0035139031879378724

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1.184588821102578

# %%
y_pred
# Out:
# array([ 9.74530108, 10.51510127, 10.67183841, 10.5023219 , 10.83308575,
#        10.58451205,  9.98040605, 10.55997206, 10.75982401, 10.82796404,
#        10.44162058, 10.69839261, 10.59384221, 10.67080746, 10.0219311 ,
#        10.36918108, 10.74974773, 10.23385993, 10.60604493, 10.79422801,
#        10.39810155, 10.33976019, 10.20050242,  9.98890576, 10.71782614,
#        10.52166113, 10.64531919, 10.28575205, 10.32402313, 10.00746677,
#        10.01086032, 10.51687214, 11.12126709, 10.38723654, 10.24641572,
#        10.56273834, 10.31296203, 10.65161775, 10.79381871, 10.6671455 ,
#        10.24682078, 10.92980476, 10.20097477, 10.7773729 ,  9.97968252,
#        10.19309248, 10.65820508,  9.82633666, 10.7154956 , 10.83435165,
#        10.85752977,  9.99166826, 10.22674716, 10.62381176, 10.54868417,
#        10.37207473, 10.22865756, 10.38240691, 10.6659435 , 10.84185563,
#        10.35256897, 10.39459377, 10.15221368, 10.99480528, 10.77428242,
# ...

# %%
sns.regplot(x="Data_Value", y="PM 2.5", data=df);

# %% [markdown]
# Applying a KNN model

# %%
# Define X and y
X=df2.drop(columns=['Data_Value'])
y=df2['Data_Value']


# Split train and test sets
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Train the model
KNN=KNeighborsRegressor()
KNN.fit(X_train,y_train)

# Evaluate the model
y_train_pred =KNN.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

y_test_pred =KNN.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

print("train r2: " + str(r2_train))
print("test r2: " + str(r2_test))
# Out:
# train r2: -0.12462578992108986
# test r2: -0.29514874524476453

# %% [markdown]
# # 2. Arizona dataset

# %%
df_asthmaarizona=df_asthma.loc[df_asthma['StateDesc'] == 'Arizona']

# %%
df_asthmaarizona
# Out:
#        Year StateAbbr StateDesc CountyName  CountyFIPS  LocationName  \
# 74     2018        AZ   Arizona       Gila        4007    4007000500
# 164    2018        AZ   Arizona       Pima        4019    4019004073
# 173    2018        AZ   Arizona       Pima        4019    4019004508
# 35532  2018        AZ   Arizona   Maricopa        4013    4013103210
# 35544  2018        AZ   Arizona   Maricopa        4013    4013104218
# ...     ...       ...       ...        ...         ...           ...
# 83738  2018        AZ   Arizona      Pinal        4021    4021000315
# 83796  2018        AZ   Arizona       Pima        4019    4019002501
# 83806  2018        AZ   Arizona       Pima        4019    4019004719
# 83807  2018        AZ   Arizona       Pima        4019    4019004070
# 83813  2018        AZ   Arizona   Maricopa        4013    4013817200
#
#       DataSource         Category  \
# 74         BRFSS  Health Outcomes
# 164        BRFSS  Health Outcomes
# ...

# %%
df_asthmaarizona.to_excel('asthmaar.xlsx')

# %%
pm10 = pd.read_excel('arizona.xlsx')

# %%
pm10
# Out:
#       pm10
# 0       43
# 1       21
# 2       20
# 3       25
# 4       17
# ...    ...
# 1511     7
# 1512     9
# 1513     5
# 1514     7
# 1515     6
#
# [1516 rows x 1 columns]

# %% [markdown]
# Linear regression model

# %%
df = pd.read_excel('asthmaarwpm10.xlsx')

# %%
df2 = df[['Data_Value','pm10']]

# %%
X=df2.drop(columns=['Data_Value']) # X is all other columns 
y=df2['Data_Value']

# %%
X.shape
# Out:
# (1516, 1)

# %%
y.shape
# Out:
# (1516,)

# %%
ln=LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model=ln.fit(X_train,y_train)

# %%
y_pred =ln.predict(X_test)

# %%
y_pred
# Out:
# array([10.55412824, 10.55412824, 10.4625371 , 10.5000062 , 10.56245471,
#        10.46670033, 10.47919003, 10.54580177, 10.67069878, 10.5000062 ,
#        10.46670033, 10.63322968, 10.54163854, 10.54996501, 10.61241351,
#        10.48335327, 10.56661794, 10.57078117, 10.45837386, 10.56661794,
#        10.57910764, 10.57078117, 10.53331207, 10.63322968, 10.50833267,
#        10.54163854, 10.62073998, 10.61657675, 10.48335327, 10.5124959 ,
#        10.54163854, 10.53331207, 10.52082237, 10.49584297, 10.58327088,
#        10.59159734, 10.45837386, 10.56245471, 10.54580177, 10.5124959 ,
#        10.50833267, 10.51665914, 10.61657675, 10.54163854, 10.54580177,
#        10.5124959 , 10.61241351, 10.45421063, 10.48335327, 10.51665914,
#        10.4500474 , 10.4750268 , 10.5249856 , 10.4750268 , 10.56245471,
#        10.52082237, 10.93714574, 10.53331207, 10.4750268 , 10.67486202,
#        10.57494441, 10.61241351, 10.4875165 , 10.54163854, 10.45837386,
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# -0.0009465542314992526

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.9618510324624443

# %%
y_pred
# Out:
# array([10.55412824, 10.55412824, 10.4625371 , 10.5000062 , 10.56245471,
#        10.46670033, 10.47919003, 10.54580177, 10.67069878, 10.5000062 ,
#        10.46670033, 10.63322968, 10.54163854, 10.54996501, 10.61241351,
#        10.48335327, 10.56661794, 10.57078117, 10.45837386, 10.56661794,
#        10.57910764, 10.57078117, 10.53331207, 10.63322968, 10.50833267,
#        10.54163854, 10.62073998, 10.61657675, 10.48335327, 10.5124959 ,
#        10.54163854, 10.53331207, 10.52082237, 10.49584297, 10.58327088,
#        10.59159734, 10.45837386, 10.56245471, 10.54580177, 10.5124959 ,
#        10.50833267, 10.51665914, 10.61657675, 10.54163854, 10.54580177,
#        10.5124959 , 10.61241351, 10.45421063, 10.48335327, 10.51665914,
#        10.4500474 , 10.4750268 , 10.5249856 , 10.4750268 , 10.56245471,
#        10.52082237, 10.93714574, 10.53331207, 10.4750268 , 10.67486202,
#        10.57494441, 10.61241351, 10.4875165 , 10.54163854, 10.45837386,
# ...

# %%
sns.regplot(x="Data_Value", y="pm10", data=df);

# %% [markdown]
# Applying KNN model

# %%
# Define X and y
X=df2.drop(columns=['Data_Value'])
y=df2['Data_Value']


# Split train and test sets
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Train the model
KNN=KNeighborsRegressor()
KNN.fit(X_train,y_train)

# Evaluate the model
y_train_pred =KNN.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

y_test_pred =KNN.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

print("train r2: " + str(r2_train))
print("test r2: " + str(r2_test))
# Out:
# train r2: -0.04530130949232336
# test r2: -0.2553391688997235

# %% [markdown]
# # 3. Air pollutants in Arizona (NO2, SO2, CO, O3)

# %%
airpollutants = pd.read_csv('pollution_us_2000_2016.csv')

# %%
airpollutants
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                          Address    State    County  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 2        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# ...

# %%
airpollutantsarizona=airpollutants.loc[airpollutants['State'] == 'Arizona']

# %%
airpollutantsarizona
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 0                 0           4           13      3002
# 1                 1           4           13      3002
# 2                 2           4           13      3002
# 3                 3           4           13      3002
# 4                 4           4           13      3002
# ...             ...         ...          ...       ...
# 1723328        1271           4           19      1028
# 1723329        1272           4           19      1028
# 1723330        1273           4           19      1028
# 1723331        1274           4           19      1028
# 1723332        1275           4           19      1028
#
#                                          Address    State    County     City  \
# 0        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1        1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# ...

# %%
airpollutantsarizona.to_excel('airpollutantsarizona.xlsx')

# %%
df4 = pd.read_excel('asthmaar3.xlsx')

# %%
df4
# Out:
#      Data_Value   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# 0          11.4  15.458333               35.0                21       33
# 1          10.3  11.208333               30.0                19       28
# 2          11.2   7.141667               19.2                 7       18
# 3          10.2  25.173913               43.0                19       41
# 4          10.9  15.366667               28.8                21       26
# ..          ...        ...                ...               ...      ...
# 786         9.4  18.587500               38.6                20       36
# 787         9.3  28.904762               50.0                19       47
# 788        10.3  20.350000               33.6                21       31
# 789        11.4  34.125000               45.0                 9       42
# 790        10.0  22.612500               33.0                20       31
#
#       O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI  SO2 Mean  \
# ...

# %%
X=df4.drop(columns=['Data_Value']) # X is all other columns 
y=df4['Data_Value']

# %%
ln=LinearRegression()

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
model=ln.fit(X_train,y_train)

# %%
y_pred =ln.predict(X_test)

# %%
y_pred
# Out:
# array([ 9.74530108, 10.51510127, 10.67183841, 10.5023219 , 10.83308575,
#        10.58451205,  9.98040605, 10.55997206, 10.75982401, 10.82796404,
#        10.44162058, 10.69839261, 10.59384221, 10.67080746, 10.0219311 ,
#        10.36918108, 10.74974773, 10.23385993, 10.60604493, 10.79422801,
#        10.39810155, 10.33976019, 10.20050242,  9.98890576, 10.71782614,
#        10.52166113, 10.64531919, 10.28575205, 10.32402313, 10.00746677,
#        10.01086032, 10.51687214, 11.12126709, 10.38723654, 10.24641572,
#        10.56273834, 10.31296203, 10.65161775, 10.79381871, 10.6671455 ,
#        10.24682078, 10.92980476, 10.20097477, 10.7773729 ,  9.97968252,
#        10.19309248, 10.65820508,  9.82633666, 10.7154956 , 10.83435165,
#        10.85752977,  9.99166826, 10.22674716, 10.62381176, 10.54868417,
#        10.37207473, 10.22865756, 10.38240691, 10.6659435 , 10.84185563,
#        10.35256897, 10.39459377, 10.15221368, 10.99480528, 10.77428242,
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# -0.11770285293444727

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.8803476452850186

# %%
sns.regplot(x="Data_Value", y="O3 AQI", data=df4);

# %% [markdown]
# Heatmap

# %%
fig, ax = plt.subplots(figsize=(15,10))

mask=np.zeros_like(df4.corr())

mask[np.triu_indices_from(mask)]=True

sns.heatmap(df4.corr(), mask=mask, annot=True, cmap='coolwarm', center=0)

plt.show()

# %%
df4.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Data_Value'}>,
#         <AxesSubplot:title={'center':'NO2 Mean'}>,
#         <AxesSubplot:title={'center':'NO2 1st Max Value'}>,
#         <AxesSubplot:title={'center':'NO2 1st Max Hour'}>],
#        [<AxesSubplot:title={'center':'NO2 AQI'}>,
#         <AxesSubplot:title={'center':'O3 Mean'}>,
#         <AxesSubplot:title={'center':'O3 1st Max Value'}>,
#         <AxesSubplot:title={'center':'O3 1st Max Hour'}>],
#        [<AxesSubplot:title={'center':'O3 AQI'}>,
#         <AxesSubplot:title={'center':'SO2 Mean'}>,
#         <AxesSubplot:title={'center':'SO2 1st Max Value'}>,
#         <AxesSubplot:title={'center':'SO2 1st Max Hour'}>],
#        [<AxesSubplot:title={'center':'SO2 AQI'}>,
#         <AxesSubplot:title={'center':'CO Mean'}>,
#         <AxesSubplot:title={'center':'CO 1st Max Value'}>,
#         <AxesSubplot:title={'center':'CO 1st Max Hour'}>]], dtype=object)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# KNN and random forest regressor

# %%
# Define X and y
X=df4.drop(columns=['Data_Value'])
y=df4['Data_Value']


# Split train and test sets
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.1, random_state=40)

# Train the model
KNN=KNeighborsRegressor()
KNN.fit(X_train,y_train)

# Evaluate the model
y_train_pred =KNN.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

y_test_pred =KNN.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

print("train r2: " + str(r2_train))
print("test r2: " + str(r2_test))
# Out:
# train r2: 0.20935753415544
# test r2: -0.9693148640267051

# %%
# Define X and y
X=df4.drop(columns=['Data_Value'])
y=df4['Data_Value']


# Split train and test sets
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# Train the model
RF=RandomForestRegressor()
RF.fit(X_train,y_train)

# Evaluate the model
y_train_pred =RF.predict(X_train)
r2_train = r2_score(y_train, y_train_pred)

y_test_pred =RF.predict(X_test)
r2_test = r2_score(y_test, y_test_pred)

print("train r2: " + str(r2_train))
print("test r2: " + str(r2_test))
# Out:
# train r2: 0.8365651368577988
# test r2: -0.15212262217992523

# %%
df4
# Out:
#      Data_Value   NO2 Mean  NO2 1st Max Value  NO2 1st Max Hour  NO2 AQI  \
# 0          11.4  15.458333               35.0                21       33
# 1          10.3  11.208333               30.0                19       28
# 2          11.2   7.141667               19.2                 7       18
# 3          10.2  25.173913               43.0                19       41
# 4          10.9  15.366667               28.8                21       26
# ..          ...        ...                ...               ...      ...
# 786         9.4  18.587500               38.6                20       36
# 787         9.3  28.904762               50.0                19       47
# 788        10.3  20.350000               33.6                21       31
# 789        11.4  34.125000               45.0                 9       42
# 790        10.0  22.612500               33.0                20       31
#
#       O3 Mean  O3 1st Max Value  O3 1st Max Hour  O3 AQI  SO2 Mean  \
# ...
